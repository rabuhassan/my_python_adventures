# %% [markdown]
# ### Practical Activity 4.1.9
# # Create Plots with Seaborn
# ----

# %% [markdown]
# ### 1. Prepara Workstation

# %%
# Import packages
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Load databases and create DataFrames
movies = pd.read_csv('movies.csv')
ott = pd.read_excel('ott.xlsx')

# View the DataFrame. 
print("movies")
print(f"{movies.shape[0]} rows for movies")
print(f"{movies.shape[1]} columns for movies")
print(f"movies has the following columns: {movies.columns}")

print("-------------")

print("ott")
print(f"{ott.shape[0]} rows for ott")
print(f"{ott.shape[1]} columns for ott")
print(f"ott has the following columns: {ott.columns}")
print("-------------")
# Out:
# movies
# 16744 rows for movies
# 11 columns for movies
# movies has the following columns: Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')
# -------------
# ott
# 16744 rows for ott
# 5 columns for ott
# ott has the following columns: Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')
# -------------

# %%
movies.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0

# %%
ott.head()
# Out:
#    ID  Netflix  Hulu  Prime Video  Disney+
# 0   1        0     0            1        0
# 1   2        0     1            0        0
# 2   3        0     0            1        0
# 3   4        1     0            0        0
# 4   5        0     0            1        0

# %%
# Merge the two DataFrames

movies_list = pd.merge(movies, ott, how='left', on='ID')
movies_list
# Out:
#           ID                                        Title  Year  Age  IMDb  \
# 0          1                                    Inception  2010  13+   8.8
# 1          2                                   The Matrix  1999  18+   8.7
# 2          3                       Avengers: Infinity War  2018  13+   8.5
# 3          4                           Back to the Future  1985   7+   8.5
# 4          5               The Good, the Bad and the Ugly  1966  18+   8.8
# 5          6            Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 6          7                                  The Pianist  2002  18+   8.5
# 7          8                             Django Unchained  2012  18+   8.4
# 8          9                      Raiders of the Lost Ark  1981   7+   8.4
# 9         10                         Inglourious Basterds  2009  18+   8.3
# 10        11                                  Taxi Driver  1976  18+   8.3
# 0                 87%                            Christopher Nolan
# 1                 87%               Lana Wachowski,Lilly Wachowski
# 2                 84%                      Anthony Russo,Joe Russo
# 3                 96%                              Robert Zemeckis
# 4                 97%                                 Sergio Leone
# 5                 97%  Bob Persichetti,Peter Ramsey,Rodney Rothman
# 6                 95%                               Roman Polanski
# 7                 87%                            Quentin Tarantino
# 8                 95%                             Steven Spielberg
# 9                 89%                            Quentin Tarantino
# 10                95%                              Martin Scorsese
# 11               100%                              Rajkumar Hirani
# 12                95%                           Guillermo del Toro
# 13                93%                             Lenny Abrahamson
# 14                97%                    Terry Gilliam,Terry Jones
# 15                95%                                 Sergio Leone
# 16                88%                             Steven Spielberg
# 17                96%                                 Harold Ramis
# 18                95%                                   Tom Hooper
# 19                95%                                  Spike Jonze
# 20                91%                         Paul Thomas Anderson
# 21                96%                                David Fincher
# 22                93%                             Jean-Marc Vallée
# 23                86%                              Stephen Chbosky
# 24                95%                                  Terry Jones
# 25                92%                                 Alex Garland
# 26                92%                             David O. Russell
# 27                90%                               Neill Blomkamp
# 28                96%                              Martin Scorsese
# 29                90%                                 Duncan Jones
# ...               ...                                          ...
# 16714             NaN                                    Mike Slee
# 16715             NaN                                  Neal Israel
# 16716             NaN                            Charles L. Draper
# 16717             NaN                                          NaN
# 16718             NaN              David Bartlett,Sebastian Peiter
# 16719             55%                   Mike Gabriel,Eric Goldberg
# 16720             NaN                                 Wayne Abbott
# 16721             NaN                                Russ Mayberry
# 16722             NaN                                  James Algar
# 16723             NaN                              Larry Lansburgh
# 16724             NaN                               Paul Schneider
# 16725             NaN                             Robert Stevenson
# 16726             NaN                               John Murlowski
# 16727             NaN                                   Nick Marck
# 16728             NaN                                 Keith Haskel
# 16729             NaN                          Sophie Elwin-Harris
# 16730             NaN                                   Jenny Kubo
# 16731             NaN                                  Glenn Weiss
# 16732             NaN                                  Gary Nelson
# 16733             NaN                                 Robert Nixon
# 16734             NaN                             Edward M. Abroms
# 16735             NaN                                          NaN
# 16736             NaN                                Molly Hermann
# 16737             NaN                             Bernard McEveety
# 16738             NaN                               Dereck Joubert
# 16739             NaN                                 Bruce Bilson
# 16740             NaN                                  Neal Israel
# 16741             NaN                                 Neil Gelinas
# 16742             NaN                         Richard Slater-Jones
# 16743             NaN                                  James Algar
#
#                                                  Genres  \
# 0                      Action,Adventure,Sci-Fi,Thriller
# 1                                         Action,Sci-Fi
# 2                               Action,Adventure,Sci-Fi
# 3                               Adventure,Comedy,Sci-Fi
# 4                                               Western
# 5              Animation,Action,Adventure,Family,Sci-Fi
# 6                             Biography,Drama,Music,War
# 7                                         Drama,Western
# 8                                      Action,Adventure
# 9                                   Adventure,Drama,War
# 10                                          Crime,Drama
# 11                                         Comedy,Drama
# 12                                    Drama,Fantasy,War
# 13                                       Drama,Thriller
# 14                             Adventure,Comedy,Fantasy
# 15                                              Western
# 16                                     Action,Adventure
# 16723     0            1        0
# 16724     0            1        0
# 16725     0            1        0
# 16726     0            1        0
# 16727     0            1        0
# 16728     0            1        0
# 16729     0            1        0
# 16730     0            1        0
# 16731     1            1        0
# 16732     0            1        0
# 16733     0            1        0
# 16734     0            0        0
# 16735     0            1        0
# 16736     0            0        1
# 16737     0            1        0
# 16738     0            1        0
# 16739     0            1        0
# 16740     0            1        0
# 16741     0            1        0
# 16742     0            1        0
# 16743     0            0        0
#
# [16744 rows x 15 columns]

# %%
# View the merged DataFrame. 
print("movies_list")
print(f"{movies_list.shape[0]} rows for movies_list")
print(f"{movies_list.shape[1]} columns for movies_list")
print(f"movies_list has the following columns: {movies_list.columns}")

print("-------------")
# Out:
# movies_list
# 16744 rows for movies_list
# 15 columns for movies_list
# movies_list has the following columns: Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime', 'Netflix', 'Hulu',
#        'Prime Video', 'Disney+'],
#       dtype='object')
# -------------

# %%
movies_list.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# 0  United States,United Kingdom  English,Japanese,French    148.0        0
# 1                 United States                  English    136.0        0
# 2                 United States                  English    149.0        0
# 3                 United States                  English    116.0        1
# 4      Italy,Spain,West Germany                  Italian    161.0        0
#
#    Hulu  Prime Video  Disney+
# 0     0            1        0
# 1     1            0        0
# 2     0            1        0
# 3     0            0        0
# 4     0            1        0

# %% [markdown]
# ### 2. Plot Counterplot
#
# Determine what age group has streamed the most movies. Based on the plot, answer the following questions:
# 1. What age group had the most-streamed movies?
# 2. Can you identify any gaps that Netflix need to address?

# %%
# Create a countplot.
sns.countplot(x='Age', hue='Netflix', data=movies_list)

# %% [markdown]
# * 18+ have streamed the most movies.
# * It appears that Netflix have far less costomers that are younger than 18. It could be that Netflix have a much smaller selection of movies that are not rated R.

# %% [markdown]
# ### 3. Histogram Plot
#
# Based on the plot, answer the following questions:
# 1. What do you understand from the histogram?
# 2. What are the outliers in the data?

# %%
# Create a histogram.
sns.histplot(data = movies_list, x='IMDb', binwidth=1)

# %% [markdown]
# * Most fall just above average.
# * There are a couple of outliers.

# %% [markdown]
# ### 4. Scatterplot
# Determine if there is a correlation between the ratings from Rotten Tomatoes and IMDb. Based on the plot, answer the following questions:
# * What can you infer about the correlation?
# * If there is a correlation, is the relationship between the ratings strong or weak and positive or negative?

# %%
# Create the scatterplot.
sns.scatterplot(x='IMDb', y='Rotten Tomatoes', data=movies_list)

# %% [markdown]
# * There is a week positive correlation.

# %% [markdown]
# ### Practical Activity 4.1.12
# # Outliers Analysis
# ----

# %%
# Create a boxplot based on species and body_mass_g.
sns.boxplot(data=movies_list, x='Age', y='IMDb')

# %% [markdown]
# ### Practical Activity 4.1.15
# # Creating a Line and Subplots
# -----

# %% [markdown]
# ### 1. Lineplot
#
# Cmparing the movies' release year and their IMDb ratings in order to answer the following questions:
# * What can you infer about the users’ ratings for movies released between 1920 and 1940?
# * What can you infer about the users’ ratings for movies released between 1960 and 1980?

# %%
# Create a simple plot.
sns.lineplot(x='Year', y='IMDb', data=movies_list)

# %%
# Create a simple plot. Remove the bands. 
sns.lineplot(x='Year', y='IMDb', data=movies_list, ci=None)

# %% [markdown]
# * Data between 1920 and 1940 is seemingly unreliable.
# * From 1960 until 2020, there has been an improvement in the data and the errors.

# %% [markdown]
# ### 2. Enhance Line Plot
# * Compare age, rating, and year of release of the movies in order to answer the following questions:
# * How would you further enhance the lineplot?
# * What can you infer about the movies with a 16+ and 18+ age limit?
# * In which year did the film industry start marking suitable movies for individuals 16+?

# %%
# Create lineplots with specification.
sns.lineplot(x = 'Year', y = 'IMDb',
             data = movies_list[movies_list['Age'].isin(['16+', '18+'])],
             hue ='Age', ci=None)

# %% [markdown]
# * Movie industry started making movies for 16+ in and around 1970.

# %% [markdown]
# ### Practical Activity 4.2.5
# # Customising Plots
# -----

# %%
movies_2010 = movies_list[movies_list['Year']>=2010]

ax = sns.countplot(x='Year', data=movies_2010)

ax.set(ylabel='Percent')

total = len(movies_2010['Year'])

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x()
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xticks(rotation=90)
plt.show()

# %%
ax = sns.displot(data=movies_list, x='IMDb', bins=10,kind='hist', 
                 palette='GnBu', aspect=1.4, kde=True)

plt.show()

# %% [markdown]
# ### Practical Activity 4.2.7
# # Highlight and Annotate Plots
# -----

# %%
sns.scatterplot(data=movies_list, x='IMDb', y='Rotten Tomatoes', hue='Netflix')

plt.show()

# %%
sns.boxplot(data=movies_list, x='Age', y='IMDb', linewidth=2, 
            notch=True, hue='Netflix', palette='Set3')

plt.show()

# %%
sns.lineplot(x = 'Year', y = 'IMDb', data=movies_list, linewidth=0)

sns.lineplot(x = 'Year', y = 'IMDb',
             data=movies_list[movies_list['Age'].isin(['16+', '18+'])], 
             hue ='Age')

sns.lineplot(x = 'Year', y = 'IMDb', 
             data=movies_list[movies_list['Age'].isin(['16+', '18+'])], 
             hue ='Age', style = 'Age', markers=True, ci=0)
