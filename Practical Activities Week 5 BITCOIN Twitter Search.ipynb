# %% [markdown]
# ### Week 5 Practical Activities

# %% [markdown]
# # 5.2.8 Practical activity: Search the Twitter API

# %% [markdown]
# ### 1. Prepare Workstation

# %%
# Import Libraries
import yaml
from yaml.loader import SafeLoader
from twitter import *

# Import the YAML file - remember to specify the whole path.
twitter_creds = yaml.safe_load(open('twitter.yaml', 'r').read())

# Pass your Twitter credentials.
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))
# Check connection.
print(twitter_api)

# Run connection test with search.
python_tweets = twitter_api.search.tweets(q='#python')

# View the output.
print(python_tweets)
# Out:
# <twitter.api.Twitter object at 0x7fe4ed24bdf0>
# {'statuses': [{'created_at': 'Thu Jun 30 16:20:01 +0000 2022', 'id': 1542543488000163841, 'id_str': '1542543488000163841', 'text': 'RT @lnbcore: #Programming languages and their uses..!\n#100DaysOfCode #coder #cybersecurity #BigData #javascript #technology #java #MachineL…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Programming', 'indices': [13, 25]}, {'text': '100DaysOfCode', 'indices': [54, 68]}, {'text': 'coder', 'indices': [69, 75]}, {'text': 'cybersecurity', 'indices': [76, 90]}, {'text': 'BigData', 'indices': [91, 99]}, {'text': 'javascript', 'indices': [100, 111]}, {'text': 'technology', 'indices': [112, 123]}, {'text': 'java', 'indices': [124, 129]}], 'symbols': [], 'user_mentions': [{'screen_name': 'lnbcore', 'name': 'Learn and Build', 'id': 1309867693516795909, 'id_str': '1309867693516795909', 'indices': [3, 11]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 390398296, 'id_str': '390398296', 'name': 'Estudios Ingleses', 'screen_name': 'Eingleses', 'location': 'Murcia. España', 'description': 'Aprende inglés.\nContacto: admin@eingleses.com', 'url': 'https://t.co/8G9fAqQC48', 'entities': {'url': {'urls': [{'url': 'https://t.co/8G9fAqQC48', 'expanded_url': 'https://eingleses.com/', 'display_url': 'eingleses.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3853, 'friends_count': 452, 'listed_count': 140, 'created_at': 'Thu Oct 13 22:37:01 +0000 2011', 'favourites_count': 995, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 25169, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000493353948/d0960a3fc70ed3cad33ba9746f0dbe85_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000493353948/d0960a3fc70ed3cad33ba9746f0dbe85_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/390398296/1417519284', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'A8C7F7', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Jun 22 08:14:42 +0000 2022', 'id': 1539522253850718208, 'id_str': '1539522253850718208', 'text': '#Programming languages and their uses..!\n#100DaysOfCode #coder #cybersecurity #BigData #javascript #technology… https://t.co/Q5xPzAqD6p', 'truncated': True, 'entities': {'hashtags': [{'text': 'Programming', 'indices': [0, 12]}, {'text': '100DaysOfCode', 'indices': [41, 55]}, {'text': 'coder', 'indices': [56, 62]}, {'text': 'cybersecurity', 'indices': [63, 77]}, {'text': 'BigData', 'indices': [78, 86]}, {'text': 'javascript', 'indices': [87, 98]}, {'text': 'technology', 'indices': [99, 110]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Q5xPzAqD6p', 'expanded_url': 'https://twitter.com/i/web/status/1539522253850718208', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [112, 135]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://m ...

# %% [markdown]
# ### 2. Identify Worldwide Trends

# %%
# Identify worldwide trends.
trends_worldwide = twitter_api.trends.available()

# How many trends are available.
print(len(trends_worldwide))

# Example of trends_worldwide.
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %% [markdown]
# ### 3. Identify Specified Cities (London and New York)

# %%
# Find London & New York.
first_city = 'London'
second_city = 'New York'

# Create a variable.
list_of_names_first_city = [_ for _ in trends_worldwide if _['name'] == first_city]
list_of_names_second_city = [_ for _ in trends_worldwide if _['name'] == second_city]

# %%
# View the output.
print(len(list_of_names_first_city))

# Use index to find London.
list_of_names_first_city[0]
# Out:
# 1
# 1
# {'name': 'London',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/44418',
#  'parentid': 23424975,
#  'country': 'United Kingdom',
#  'woeid': 44418,
#  'countryCode': 'GB'}

# %%
# View the output.
print(len(list_of_names_second_city))

# Use index to find New York.
list_of_names_second_city[0]
# Out:
# 1
# {'name': 'New York',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/2459115',
#  'parentid': 23424977,
#  'country': 'United States',
#  'woeid': 2459115,
#  'countryCode': 'US'}

# %%
# List of 'where on earth identifiers' (woeid).
# London
list_of_names_first_city[0]['woeid']
# Out:
# 44418

# %%
# List of 'where on earth identifiers' (woeid).
# New York
list_of_names_second_city[0]['woeid']
# Out:
# 2459115

# %% [markdown]
# ### 4. Trends in London

# %%
# Look at common trends in London.
london_trends = twitter_api.trends.place(_id = list_of_names_first_city[0]['woeid'])

# View the output.
london_trends
# Out:
# [{'trends': [{'name': '#FutureOfBritain',
#     'url': 'http://twitter.com/search?q=%23FutureOfBritain',
#     'promoted_content': None,
#     'query': '%23FutureOfBritain',
#     'tweet_volume': None},
#    {'name': '#PrideMonth',
#     'url': 'http://twitter.com/search?q=%23PrideMonth',
#     'promoted_content': None,
#     'query': '%23PrideMonth',
#     'tweet_volume': 45314},
#    {'name': 'Deco',
#     'url': 'http://twitter.com/search?q=Deco',
#     'promoted_content': None,
#     'query': 'Deco',
#     'tweet_volume': 50245},
#    {'name': 'size 10',
#     'url': 'http://twitter.com/search?q=%22size+10%22',
#     'promoted_content': None,
#     'query': '%22size+10%22',
#     'tweet_volume': None},
#    {'name': '#journorequest',
#     'url': 'http://twitter.com/search?q=%23journorequest',
#     'promoted_content': None,
#     'query': '%23journorequest',
#     'tweet_volume': None},
#    {'name': '#RCGPAC',
#     'url': 'http://twitter.com/search?q=%23RCGPAC',
#     'promoted_content': None,
#     'query': '%23RCGPAC',
#     'tweet_volume': None},
#    {'name': 'Foreign Secretary',
#     'url': 'http://twitter.com/search?q=%22Foreign+Secretary%22',
#     'promoted_content': None,
#     'query': '%22Foreign+Secretary%22',
#     'tweet_volume': None},
#    {'name': 'Meghan',
#     'url': 'http://twitter.com/search?q=Meghan',
#     'promoted_content': None,
#     'query': 'Meghan',
#     'tweet_volume': 33248},
#    {'name': 'Nadine Dorries',
#     'url': 'http://twitter.com/search?q=%22Nadine+Dorries%22',
#     'promoted_content': None,
#     'query': '%22Nadine+Dorries%22',
#     'tweet_volume': None},
#    {'name': 'Katie Boulter',
#     'url': 'http://twitter.com/search?q=%22Katie+Boulter%22',
#     'promoted_content': None,
#     'query': '%22Katie+Boulter%22',
#     'tweet_volume': None},
#    {'name': 'Liam Broady',
#     'url': 'http://twitter.com/search?q=%22Liam+Broady%22',
#     'promoted_content': None,
#     'query': '%22Liam+Broady%22',
#     'tweet_volume': None},
#    {'name': 'Rugby League',
#     'url': 'http://twitter.com/search?q=%22Rugby+League%22',
#     'promoted_content': None,
#     'query': '%22Rugby+League%22',
#     'tweet_volume': None},
#    {'name': 'Jason Robinson',
#     'url': 'http://twitter.com/search?q=%22Jason+Robinson%22',
#     'promoted_content': None,
#     'query': '%22Jason+Robinson%22',
#     'tweet_volume': None},
#    {'name': 'Logan Mwangi',
#     'url': 'http://twitter.com/search?q=%22Logan+Mwangi%22',
#     'promoted_content': None,
#     'query': '%22Logan+Mwangi%22',
#     'tweet_volume': None},
#    {'name': 'ATEEZ THE MOVEMENT',
#     'url': 'http://twitter.com/search?q=%22ATEEZ+THE+MOVEMENT%22',
#     'promoted_content': None,
#     'query': '%22ATEEZ+THE+MOVEMENT%22',
#     'tweet_volume': 97194},
#    {'name': 'Media and Sport',
#     'url': 'http://twitter.com/search?q=%22Media+and+Sport%22',
#     'promoted_content': None,
#     'query': '%22Media+and+Sport%22',
#     'tweet_volume': None},
#    {'name': 'Rugby Union',
#     'url': 'http://twitter.com/search?q=%22Rugby+Union%22',
#     'promoted_content': None,
#     'query': '%22Rugby+Union%22',
#     'tweet_volume': None},
#    {'name': 'Bloody Marys',
#     'url': 'http://twitter.com/search?q=%22Bloody+Marys%22',
#     'promoted_content': None,
#     'query': '%22Bloody+Marys%22',
#     'tweet_volume': None},
#    {'name': 'Karolina Pliskova',
#     'url': 'http://twitter.com/search?q=%22Karolina+Pliskova%22',
#     'promoted_content': None,
#     'query': '%22Karolina+Pliskova%22',
#     'tweet_volume': None},
#    {'name': 'Culture Secretary',
#     'url': 'http://twitter.com/search?q=%22Culture+Secretary%22',
#     'promoted_content': None,
#     'query': '%22Culture+Secretary%22',
#     'tweet_volume': None},
#    {'name': 'Richarlison',
#     'url': 'http://twitter.com/search?q=Richarlison',
#     'promoted_content': None,
#     'query': 'Richarlison',
#     'tweet_volume': 87978},
#    {'name': 'Usher',
#     'url': 'http://twitter.com/search?q=Usher',
#     'promoted_content': None,
#     'query': 'Usher',
#     'tweet_volume': 20579},
#    {'name': 'Russo',
#     'url': 'http://twitter.com/search?q=Russo',
#     'promoted_content': None,
#     'query': 'Russo',
#     'tweet_volume': 13204},
#    {'name': 'Secretary of State for Digital',
#     'url': 'http://twitter.com/search?q=%22Secretary+of+State+for+Digital%22',
#     'promoted_content': None,
#     'query': '%22Secretary+of+State+for+Digital%22',
#     'tweet_volume': None},
#    {'name': 'Snake Island',
#     'url': 'http://twitter.com/search?q=%22Snake+Island%22',
#     'promoted_content': None,
#     'query': '%22Snake+Island%22',
#     'tweet_volume': 54775},
#    {'name': 'taeyong',
#     'url': 'http://twitter.com/search?q=taeyong',
#     'promoted_content': None,
#     'query': 'taeyong',
#     'tweet_volume': 379059},
#    {'name': 'St Helens',
#     'url': 'http://twitter.com/search?q=%22St+Helens%22',
#     'promoted_content': None,
#     'query': '%22St+Helens%22',
#     'tweet_volume': None},
#    {'name': 'Daniel Ballard',
#     'url': 'http://twitter.com/search?q=%22Daniel+Ballard%22',
#     'promoted_content': None,
#     'query': '%22Daniel+Ballard%22',
#     'tweet_volume': None},
#    {'name': 'Lingard',
#     'url': 'http://twitter.com/search?q=Lingard',
#     'promoted_content': None,
#     'query': 'Lingard',
#     'tweet_volume': None},
#    {'name': 'RIP Rocky',
#     'url': 'http://twitter.com/search?q=%22RIP+Rocky%22',
#     'promoted_content': None,
#     'query': '%22RIP+Rocky%22',
#     'tweet_volume': None},
#    {'name': 'Shrewsbury',
#     'url': 'http://twitter.com/search?q=Shrewsbury',
#     'promoted_content': None,
#     'query': 'Shrewsbury',
#     'tweet_volume': None},
#    {'name': 'size 9',
#     'url': 'http://twitter.com/search?q=%22size+9%22',
#     'promoted_content': None,
#     'query': '%22size+9%22',
#     'tweet_volume': 13112},
#    {'name': 'Bernie Ecclestone',
#     'url': 'http://twitter.com/search?q=%22Bernie+Ecclestone%22',
#     'promoted_content': None,
#     'query': '%22Bernie+Ecclestone%22',
#     'tweet_volume': 10176},
#    {'name': 'Gavin Williamson',
#     'url': 'http://twitter.com/search?q=%22Gavin+Williamson%22',
#     'promoted_content': None,
#     'query': '%22Gavin+Williamson%22',
#     'tweet_volume': None},
#    {'name': 'Yarmouth',
#     'url': 'http://twitter.com/search?q=Yarmouth',
#     'promoted_content': None,
#     'query': 'Yarmouth',
#     'tweet_volume': None},
#    {'name': 'Perisic',
#     'url': 'http://twitter.com/search?q=Perisic',
#     'promoted_content': None,
#     'query': 'Perisic',
#     'tweet_volume': None},
#    {'name': 'Captain Tom',
#     'url': 'http://twitter.com/search?q=%22Captain+Tom%22',
#     'promoted_content': None,
#     'query': '%22Captain+Tom%22',
#     'tweet_volume': None},
#    {'name': '2.5% of GDP',
#     'url': 'http://twitter.com/search?q=%222.5%25+of+GDP%22',
#     'promoted_content': None,
#     'query': '%222.5%25+of+GDP%22',
#     'tweet_volume': None},
#    {'name': 'sabrina',
#     'url': 'http://twitter.com/search?q=sabrina',
#     'promoted_content': None,
#     'query': 'sabrina',
#     'tweet_volume': 28224},
#    {'name': 'Bissouma',
#     'url': 'http://twitter.com/search?q=Bissouma',
#     'promoted_content': None,
#     'query': 'Bissouma',
#     'tweet_volume': None},
#    {'name': 'Monkey Island',
#     'url': 'http://twitter.com/search?q=%22Monkey+Island%22',
#     'promoted_content': None,
#     'query': '%22Monkey+Island%22',
#     'tweet_volume': None},
#    {'name': 'Moyes',
#     'url': 'http://twitter.com/search?q=Moyes',
#     'promoted_content': None,
#     'query': 'Moyes',
#     'tweet_volume': None},
#    {'name': 'Arlene',
#     'url': 'http://twitter.com/search?q=Arlene',
#     'promoted_content': None,
#     'query': 'Arlene',
#     'tweet_volume': None},
#    {'name': 'Forster',
#     'url': 'http://twitter.com/search?q=Forster',
#     'promoted_content': None,
#     'query': 'Forster',
#     'tweet_volume': None},
#    {'name': 'Danjuma',
#     'url': 'http://twitter.com/search?q=Danjuma',
#     'promoted_content': None,
#     'query': 'Danjuma',
#     'tweet_volume': None},
#    {'name': 'Natalie McGarry',
#     'url': 'http://twitter.com/search?q=%22Natalie+McGarry%22',
#     'promoted_content': None,
#     'query': '%22Natalie+McGarry%22',
#     'tweet_volume': None},
#    {'name': 'Haydock',
#     'url': 'http://twitter.com/search?q=Haydock',
#     'promoted_content': None,
#     'query': 'Haydock',
#     'tweet_volume': None},
#    {'name': 'Ronaldinho',
#     'url': 'http://twitter.com/search?q=Ronaldinho',
#     'promoted_content': None,
#     'query': 'Ronaldinho',
#     'tweet_volume': 10451},
#    {'name': 'Vladimir Putin',
#     'url': 'http://twitter.com/search?q=%22Vladimir+Putin%22',
#     'promoted_content': None,
#     'query': '%22Vladimir+Putin%22',
#     'tweet_volume': 36939}],
#   'as_of': '2022-06-30T16:38:41Z',
#   'created_at': '2022-06-29T15:31:34Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
# View output as a DataFrame.
# Import Pandas.
import pandas as pd

# Create a DataFrame.
london_trends_pd = pd.DataFrame(london_trends[0]['trends'])

# View the DataFrame.
london_trends_pd
# Out:
#                               name  \
# 0                 #FutureOfBritain
# 1                      #PrideMonth
# 2                             Deco
# 3                          size 10
# 4                   #journorequest
# 5                          #RCGPAC
# 6                Foreign Secretary
# 7                           Meghan
# 8                   Nadine Dorries
# 9                    Katie Boulter
# 10                     Liam Broady
# 11                    Rugby League
# 12                  Jason Robinson
# 13                    Logan Mwangi
# 14              ATEEZ THE MOVEMENT
# 15                 Media and Sport
# 16                     Rugby Union
# 17                    Bloody Marys
# 18               Karolina Pliskova
# 19               Culture Secretary
# 20                     Richarlison
# 21                           Usher
# 22                           Russo
# 23  Secretary of State for Digital
# 24                    Snake Island
# 25                         taeyong
# 26                       St Helens
# 27                  Daniel Ballard
# 28                         Lingard
# 29                       RIP Rocky
# 30                      Shrewsbury
# 31                          size 9
# 32               Bernie Ecclestone
# 33                Gavin Williamson
# 34                        Yarmouth
# 35                         Perisic
# 36                     Captain Tom
# 37                     2.5% of GDP
# 38                         sabrina
# 39                        Bissouma
# 40                   Monkey Island
# 41                           Moyes
# 42                          Arlene
# 43                         Forster
# 44                         Danjuma
# 45                 Natalie McGarry
# 46                         Haydock
# 47                      Ronaldinho
# 48                  Vladimir Putin
#
#                                                   url promoted_content  \
# 0      http://twitter.com/search?q=%23FutureOfBritain             None
# 1           http://twitter.com/search?q=%23PrideMonth             None
# 2                    http://twitter.com/search?q=Deco             None
# 3           http://twitter.com/search?q=%22size+10%22             None
# 4        http://twitter.com/search?q=%23journorequest             None
# 5               http://twitter.com/search?q=%23RCGPAC             None
# 6   http://twitter.com/search?q=%22Foreign+Secreta...             None
# 7                  http://twitter.com/search?q=Meghan             None
# 8    http://twitter.com/search?q=%22Nadine+Dorries%22             None
# 9     http://twitter.com/search?q=%22Katie+Boulter%22             None
# 10      http://twitter.com/search?q=%22Liam+Broady%22             None
# 11     http://twitter.com/search?q=%22Rugby+League%22             None
# 12   http://twitter.com/search?q=%22Jason+Robinson%22             None
# 13     http://twitter.com/search?q=%22Logan+Mwangi%22             None
# 14  http://twitter.com/search?q=%22ATEEZ+THE+MOVEM...             None
# 15  http://twitter.com/search?q=%22Media+and+Sport%22             None
# 16      http://twitter.com/search?q=%22Rugby+Union%22             None
# 17     http://twitter.com/search?q=%22Bloody+Marys%22             None
# 18  http://twitter.com/search?q=%22Karolina+Plisko...             None
# 19  http://twitter.com/search?q=%22Culture+Secreta...             None
# 20            http://twitter.com/search?q=Richarlison             None
# 21                  http://twitter.com/search?q=Usher             None
# 22                  http://twitter.com/search?q=Russo             None
# 23  http://twitter.com/search?q=%22Secretary+of+St...             None
# 24     http://twitter.com/search?q=%22Snake+Island%22             None
# 25                http://twitter.com/search?q=taeyong             None
# 26        http://twitter.com/search?q=%22St+Helens%22             None
# 27   http://twitter.com/search?q=%22Daniel+Ballard%22             None
# 28                http://twitter.com/search?q=Lingard             None
# 29        http://twitter.com/search?q=%22RIP+Rocky%22             None
# 30             http://twitter.com/search?q=Shrewsbury             None
# 31           http://twitter.com/search?q=%22size+9%22             None
# 32  http://twitter.com/search?q=%22Bernie+Ecclesto...             None
# 33  http://twitter.com/search?q=%22Gavin+Williamso...             None
# 34               http://twitter.com/search?q=Yarmouth             None
# 35                http://twitter.com/search?q=Perisic             None
# 36      http://twitter.com/search?q=%22Captain+Tom%22             None
# 37    http://twitter.com/search?q=%222.5%25+of+GDP%22             None
# 38                http://twitter.com/search?q=sabrina             None
# 39               http://twitter.com/search?q=Bissouma             None
# 40    http://twitter.com/search?q=%22Monkey+Island%22             None
# 41                  http://twitter.com/search?q=Moyes             None
# 42                 http://twitter.com/search?q=Arlene             None
# 43                http://twitter.com/search?q=Forster             None
# 44                http://twitter.com/search?q=Danjuma             None
# 45  http://twitter.com/search?q=%22Natalie+McGarry%22             None
# 46                http://twitter.com/search?q=Haydock             None
# 47             http://twitter.com/search?q=Ronaldinho             None
# 48   http://twitter.com/search?q=%22Vladimir+Putin%22             None
#
#                                    query  tweet_volume
# 0                     %23FutureOfBritain           NaN
# 1                          %23PrideMonth       45314.0
# 2                                   Deco       50245.0
# 3                          %22size+10%22           NaN
# 4                       %23journorequest           NaN
# 5                              %23RCGPAC           NaN
# 6                %22Foreign+Secretary%22           NaN
# 7                                 Meghan       33248.0
# 8                   %22Nadine+Dorries%22           NaN
# 9                    %22Katie+Boulter%22           NaN
# 10                     %22Liam+Broady%22           NaN
# 11                    %22Rugby+League%22           NaN
# 12                  %22Jason+Robinson%22           NaN
# 13                    %22Logan+Mwangi%22           NaN
# 14              %22ATEEZ+THE+MOVEMENT%22       97194.0
# 15                 %22Media+and+Sport%22           NaN
# 16                     %22Rugby+Union%22           NaN
# 17                    %22Bloody+Marys%22           NaN
# 18               %22Karolina+Pliskova%22           NaN
# 19               %22Culture+Secretary%22           NaN
# 20                           Richarlison       87978.0
# 21                                 Usher       20579.0
# 22                                 Russo       13204.0
# 23  %22Secretary+of+State+for+Digital%22           NaN
# 24                    %22Snake+Island%22       54775.0
# 25                               taeyong      379059.0
# 26                       %22St+Helens%22           NaN
# 27                  %22Daniel+Ballard%22           NaN
# 28                               Lingard           NaN
# 29                       %22RIP+Rocky%22           NaN
# 30                            Shrewsbury           NaN
# 31                          %22size+9%22       13112.0
# 32               %22Bernie+Ecclestone%22       10176.0
# 33                %22Gavin+Williamson%22           NaN
# 34                              Yarmouth           NaN
# 35                               Perisic           NaN
# 36                     %22Captain+Tom%22           NaN
# 37                   %222.5%25+of+GDP%22           NaN
# 38                               sabrina       28224.0
# 39                              Bissouma           NaN
# 40                   %22Monkey+Island%22           NaN
# 41                                 Moyes           NaN
# 42                                Arlene           NaN
# 43                               Forster           NaN
# 44                               Danjuma           NaN
# 45                 %22Natalie+McGarry%22           NaN
# 46                               Haydock           NaN
# 47                            Ronaldinho       10451.0
# 48                  %22Vladimir+Putin%22       36939.0

# %%
# Limit the output to more than 50k tweets.
london_trends_50k_pd = london_trends_pd[london_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(london_trends_50k_pd.shape)
london_trends_50k_pd
# Out:
# (5, 5)
#                   name                                                url  \
# 25             taeyong                http://twitter.com/search?q=taeyong
# 14  ATEEZ THE MOVEMENT  http://twitter.com/search?q=%22ATEEZ+THE+MOVEM...
# 20         Richarlison            http://twitter.com/search?q=Richarlison
# 24        Snake Island     http://twitter.com/search?q=%22Snake+Island%22
# 2                 Deco                   http://twitter.com/search?q=Deco
#
#    promoted_content                     query  tweet_volume
# 25             None                   taeyong      379059.0
# 14             None  %22ATEEZ+THE+MOVEMENT%22       97194.0
# 20             None               Richarlison       87978.0
# 24             None        %22Snake+Island%22       54775.0
# 2              None                      Deco       50245.0

# %%
# Save output as CSV file.
london_trends_50k_pd.to_csv('london_50k.csv', index=False)

# %% [markdown]
# ### 5. Trends in New York

# %%
# Look at common trends in New York.
newyork_trends = twitter_api.trends.place(_id = list_of_names_second_city[0]['woeid'])

# View the output.
newyork_trends
# Out:
# [{'trends': [{'name': 'Mitch',
#     'url': 'http://twitter.com/search?q=Mitch',
#     'promoted_content': None,
#     'query': 'Mitch',
#     'tweet_volume': 64900},
#    {'name': 'Upper East Side',
#     'url': 'http://twitter.com/search?q=%22Upper+East+Side%22',
#     'promoted_content': None,
#     'query': '%22Upper+East+Side%22',
#     'tweet_volume': 15504},
#    {'name': 'Kentucky',
#     'url': 'http://twitter.com/search?q=Kentucky',
#     'promoted_content': None,
#     'query': 'Kentucky',
#     'tweet_volume': 34932},
#    {'name': 'Usher',
#     'url': 'http://twitter.com/search?q=Usher',
#     'promoted_content': None,
#     'query': 'Usher',
#     'tweet_volume': 26231},
#    {'name': '#KetanjiBrownJackson',
#     'url': 'http://twitter.com/search?q=%23KetanjiBrownJackson',
#     'promoted_content': None,
#     'query': '%23KetanjiBrownJackson',
#     'tweet_volume': None},
#    {'name': 'Justice Jackson',
#     'url': 'http://twitter.com/search?q=%22Justice+Jackson%22',
#     'promoted_content': None,
#     'query': '%22Justice+Jackson%22',
#     'tweet_volume': 82811},
#    {'name': 'Remain in Mexico',
#     'url': 'http://twitter.com/search?q=%22Remain+in+Mexico%22',
#     'promoted_content': None,
#     'query': '%22Remain+in+Mexico%22',
#     'tweet_volume': 19749},
#    {'name': 'Clean Air Act',
#     'url': 'http://twitter.com/search?q=%22Clean+Air+Act%22',
#     'promoted_content': None,
#     'query': '%22Clean+Air+Act%22',
#     'tweet_volume': 21310},
#    {'name': 'The EPA',
#     'url': 'http://twitter.com/search?q=%22The+EPA%22',
#     'promoted_content': None,
#     'query': '%22The+EPA%22',
#     'tweet_volume': 115446},
#    {'name': '#thursdayvibes',
#     'url': 'http://twitter.com/search?q=%23thursdayvibes',
#     'promoted_content': None,
#     'query': '%23thursdayvibes',
#     'tweet_volume': 18390},
#    {'name': '#SocialMediaDay',
#     'url': 'http://twitter.com/search?q=%23SocialMediaDay',
#     'promoted_content': None,
#     'query': '%23SocialMediaDay',
#     'tweet_volume': 19022},
#    {'name': '#ClimateCrisis',
#     'url': 'http://twitter.com/search?q=%23ClimateCrisis',
#     'promoted_content': None,
#     'query': '%23ClimateCrisis',
#     'tweet_volume': 10037},
#    {'name': 'Christian Taliban',
#     'url': 'http://twitter.com/search?q=%22Christian+Taliban%22',
#     'promoted_content': None,
#     'query': '%22Christian+Taliban%22',
#     'tweet_volume': 41226},
#    {'name': '#WAKEUPWORLD',
#     'url': 'http://twitter.com/search?q=%23WAKEUPWORLD',
#     'promoted_content': None,
#     'query': '%23WAKEUPWORLD',
#     'tweet_volume': 82210},
#    {'name': 'Jon Voight',
#     'url': 'http://twitter.com/search?q=%22Jon+Voight%22',
#     'promoted_content': None,
#     'query': '%22Jon+Voight%22',
#     'tweet_volume': None},
#    {'name': 'ATEEZ THE MOVEMENT',
#     'url': 'http://twitter.com/search?q=%22ATEEZ+THE+MOVEMENT%22',
#     'promoted_content': None,
#     'query': '%22ATEEZ+THE+MOVEMENT%22',
#     'tweet_volume': 101910},
#    {'name': 'McConnell',
#     'url': 'http://twitter.com/search?q=McConnell',
#     'promoted_content': None,
#     'query': 'McConnell',
#     'tweet_volume': 66101},
#    {'name': 'Vedo',
#     'url': 'http://twitter.com/search?q=Vedo',
#     'promoted_content': None,
#     'query': 'Vedo',
#     'tweet_volume': 10195},
#    {'name': 'Eric Bellinger',
#     'url': 'http://twitter.com/search?q=%22Eric+Bellinger%22',
#     'promoted_content': None,
#     'query': '%22Eric+Bellinger%22',
#     'tweet_volume': None},
#    {'name': 'NICKI EVE',
#     'url': 'http://twitter.com/search?q=%22NICKI+EVE%22',
#     'promoted_content': None,
#     'query': '%22NICKI+EVE%22',
#     'tweet_volume': 13074},
#    {'name': 'West Virginia',
#     'url': 'http://twitter.com/search?q=%22West+Virginia%22',
#     'promoted_content': None,
#     'query': '%22West+Virginia%22',
#     'tweet_volume': 19117},
#    {'name': 'Dear Dan Rather',
#     'url': 'http://twitter.com/search?q=%22Dear+Dan+Rather%22',
#     'promoted_content': None,
#     'query': '%22Dear+Dan+Rather%22',
#     'tweet_volume': None},
#    {'name': 'Trump-era',
#     'url': 'http://twitter.com/search?q=Trump-era',
#     'promoted_content': None,
#     'query': 'Trump-era',
#     'tweet_volume': None},
#    {'name': 'Theo',
#     'url': 'http://twitter.com/search?q=Theo',
#     'promoted_content': None,
#     'query': 'Theo',
#     'tweet_volume': 39438},
#    {'name': 'Kagan',
#     'url': 'http://twitter.com/search?q=Kagan',
#     'promoted_content': None,
#     'query': 'Kagan',
#     'tweet_volume': 22412},
#    {'name': 'Dear Supreme Court',
#     'url': 'http://twitter.com/search?q=%22Dear+Supreme+Court%22',
#     'promoted_content': None,
#     'query': '%22Dear+Supreme+Court%22',
#     'tweet_volume': 13176},
#    {'name': '$25 USD',
#     'url': 'http://twitter.com/search?q=%22%2425+USD%22',
#     'promoted_content': None,
#     'query': '%22%2425+USD%22',
#     'tweet_volume': 10716},
#    {'name': 'Snake Island',
#     'url': 'http://twitter.com/search?q=%22Snake+Island%22',
#     'promoted_content': None,
#     'query': '%22Snake+Island%22',
#     'tweet_volume': 56158},
#    {'name': 'Superstar',
#     'url': 'http://twitter.com/search?q=Superstar',
#     'promoted_content': None,
#     'query': 'Superstar',
#     'tweet_volume': 37077},
#    {'name': 'Chevron',
#     'url': 'http://twitter.com/search?q=Chevron',
#     'promoted_content': None,
#     'query': 'Chevron',
#     'tweet_volume': None},
#    {'name': 'Jesus is Lord',
#     'url': 'http://twitter.com/search?q=%22Jesus+is+Lord%22',
#     'promoted_content': None,
#     'query': '%22Jesus+is+Lord%22',
#     'tweet_volume': None},
#    {'name': 'Leahy',
#     'url': 'http://twitter.com/search?q=Leahy',
#     'promoted_content': None,
#     'query': 'Leahy',
#     'tweet_volume': None},
#    {'name': 'Jimbo',
#     'url': 'http://twitter.com/search?q=Jimbo',
#     'promoted_content': None,
#     'query': 'Jimbo',
#     'tweet_volume': None},
#    {'name': 'Judge Jackson',
#     'url': 'http://twitter.com/search?q=%22Judge+Jackson%22',
#     'promoted_content': None,
#     'query': '%22Judge+Jackson%22',
#     'tweet_volume': 15659},
#    {'name': 'My Way',
#     'url': 'http://twitter.com/search?q=%22My+Way%22',
#     'promoted_content': None,
#     'query': '%22My+Way%22',
#     'tweet_volume': 200351},
#    {'name': 'Kaitlin Armstrong',
#     'url': 'http://twitter.com/search?q=%22Kaitlin+Armstrong%22',
#     'promoted_content': None,
#     'query': '%22Kaitlin+Armstrong%22',
#     'tweet_volume': None},
#    {'name': 'Independence Day',
#     'url': 'http://twitter.com/search?q=%22Independence+Day%22',
#     'promoted_content': None,
#     'query': '%22Independence+Day%22',
#     'tweet_volume': 17754},
#    {'name': 'Joe Rogan',
#     'url': 'http://twitter.com/search?q=%22Joe+Rogan%22',
#     'promoted_content': None,
#     'query': '%22Joe+Rogan%22',
#     'tweet_volume': 21042},
#    {'name': 'Cuphead DLC',
#     'url': 'http://twitter.com/search?q=%22Cuphead+DLC%22',
#     'promoted_content': None,
#     'query': '%22Cuphead+DLC%22',
#     'tweet_volume': None},
#    {'name': 'Clean Power Plan',
#     'url': 'http://twitter.com/search?q=%22Clean+Power+Plan%22',
#     'promoted_content': None,
#     'query': '%22Clean+Power+Plan%22',
#     'tweet_volume': None},
#    {'name': 'SCOTUS EPA',
#     'url': 'http://twitter.com/search?q=%22SCOTUS+EPA%22',
#     'promoted_content': None,
#     'query': '%22SCOTUS+EPA%22',
#     'tweet_volume': 27673},
#    {'name': 'Roberts and Kavanaugh',
#     'url': 'http://twitter.com/search?q=%22Roberts+and+Kavanaugh%22',
#     'promoted_content': None,
#     'query': '%22Roberts+and+Kavanaugh%22',
#     'tweet_volume': None},
#    {'name': 'NATO',
#     'url': 'http://twitter.com/search?q=NATO',
#     'promoted_content': None,
#     'query': 'NATO',
#     'tweet_volume': 556063},
#    {'name': 'Dune 2',
#     'url': 'http://twitter.com/search?q=%22Dune+2%22',
#     'promoted_content': None,
#     'query': '%22Dune+2%22',
#     'tweet_volume': None},
#    {'name': 'King Mack',
#     'url': 'http://twitter.com/search?q=%22King+Mack%22',
#     'promoted_content': None,
#     'query': '%22King+Mack%22',
#     'tweet_volume': None},
#    {'name': "Florida's 15",
#     'url': 'http://twitter.com/search?q=%22Florida%27s+15%22',
#     'promoted_content': None,
#     'query': '%22Florida%27s+15%22',
#     'tweet_volume': None},
#    {'name': 'Wordle 376 X',
#     'url': 'http://twitter.com/search?q=%22Wordle+376+X%22',
#     'promoted_content': None,
#     'query': '%22Wordle+376+X%22',
#     'tweet_volume': None},
#    {'name': 'Confessions',
#     'url': 'http://twitter.com/search?q=Confessions',
#     'promoted_content': None,
#     'query': 'Confessions',
#     'tweet_volume': None},
#    {'name': 'Planet Earth',
#     'url': 'http://twitter.com/search?q=%22Planet+Earth%22',
#     'promoted_content': None,
#     'query': '%22Planet+Earth%22',
#     'tweet_volume': 21559},
#    {'name': 'Daily Quordle 157',
#     'url': 'http://twitter.com/search?q=%22Daily+Quordle+157%22',
#     'promoted_content': None,
#     'query': '%22Daily+Quordle+157%22',
#     'tweet_volume': None}],
#   'as_of': '2022-06-30T16:58:27Z',
#   'created_at': '2022-06-26T05:04:17Z',
#   'locations': [{'name': 'New York', 'woeid': 2459115}]}]

# %%
# View output as a DataFrame.

# Create a DataFrame.
newyork_trends_pd = pd.DataFrame(newyork_trends[0]['trends'])

# View the DataFrame.
newyork_trends_pd
# Out:
#                      name                                                url  \
# 0                   Mitch                  http://twitter.com/search?q=Mitch
# 1         Upper East Side  http://twitter.com/search?q=%22Upper+East+Side%22
# 2                Kentucky               http://twitter.com/search?q=Kentucky
# 3                   Usher                  http://twitter.com/search?q=Usher
# 4    #KetanjiBrownJackson  http://twitter.com/search?q=%23KetanjiBrownJac...
# 5         Justice Jackson  http://twitter.com/search?q=%22Justice+Jackson%22
# 6        Remain in Mexico  http://twitter.com/search?q=%22Remain+in+Mexic...
# 7           Clean Air Act    http://twitter.com/search?q=%22Clean+Air+Act%22
# 8                 The EPA          http://twitter.com/search?q=%22The+EPA%22
# 9          #thursdayvibes       http://twitter.com/search?q=%23thursdayvibes
# 10        #SocialMediaDay      http://twitter.com/search?q=%23SocialMediaDay
# 11         #ClimateCrisis       http://twitter.com/search?q=%23ClimateCrisis
# 12      Christian Taliban  http://twitter.com/search?q=%22Christian+Talib...
# 13           #WAKEUPWORLD         http://twitter.com/search?q=%23WAKEUPWORLD
# 14             Jon Voight       http://twitter.com/search?q=%22Jon+Voight%22
# 15     ATEEZ THE MOVEMENT  http://twitter.com/search?q=%22ATEEZ+THE+MOVEM...
# 16              McConnell              http://twitter.com/search?q=McConnell
# 17                   Vedo                   http://twitter.com/search?q=Vedo
# 18         Eric Bellinger   http://twitter.com/search?q=%22Eric+Bellinger%22
# 19              NICKI EVE        http://twitter.com/search?q=%22NICKI+EVE%22
# 20          West Virginia    http://twitter.com/search?q=%22West+Virginia%22
# 21        Dear Dan Rather  http://twitter.com/search?q=%22Dear+Dan+Rather%22
# 22              Trump-era              http://twitter.com/search?q=Trump-era
# 23                   Theo                   http://twitter.com/search?q=Theo
# 24                  Kagan                  http://twitter.com/search?q=Kagan
# 25     Dear Supreme Court  http://twitter.com/search?q=%22Dear+Supreme+Co...
# 26                $25 USD        http://twitter.com/search?q=%22%2425+USD%22
# 27           Snake Island     http://twitter.com/search?q=%22Snake+Island%22
# 28              Superstar              http://twitter.com/search?q=Superstar
# 29                Chevron                http://twitter.com/search?q=Chevron
# 30          Jesus is Lord    http://twitter.com/search?q=%22Jesus+is+Lord%22
# 31                  Leahy                  http://twitter.com/search?q=Leahy
# 32                  Jimbo                  http://twitter.com/search?q=Jimbo
# 33          Judge Jackson    http://twitter.com/search?q=%22Judge+Jackson%22
# 34                 My Way           http://twitter.com/search?q=%22My+Way%22
# 35      Kaitlin Armstrong  http://twitter.com/search?q=%22Kaitlin+Armstro...
# 36       Independence Day  http://twitter.com/search?q=%22Independence+Da...
# 37              Joe Rogan        http://twitter.com/search?q=%22Joe+Rogan%22
# 38            Cuphead DLC      http://twitter.com/search?q=%22Cuphead+DLC%22
# 39       Clean Power Plan  http://twitter.com/search?q=%22Clean+Power+Pla...
# 40             SCOTUS EPA       http://twitter.com/search?q=%22SCOTUS+EPA%22
# 41  Roberts and Kavanaugh  http://twitter.com/search?q=%22Roberts+and+Kav...
# 42                   NATO                   http://twitter.com/search?q=NATO
# 43                 Dune 2           http://twitter.com/search?q=%22Dune+2%22
# 44              King Mack        http://twitter.com/search?q=%22King+Mack%22
# 45           Florida's 15   http://twitter.com/search?q=%22Florida%27s+15%22
# 46           Wordle 376 X     http://twitter.com/search?q=%22Wordle+376+X%22
# 47            Confessions            http://twitter.com/search?q=Confessions
# 48           Planet Earth     http://twitter.com/search?q=%22Planet+Earth%22
# 49      Daily Quordle 157  http://twitter.com/search?q=%22Daily+Quordle+1...
#
#    promoted_content                        query  tweet_volume
# 0              None                        Mitch       64900.0
# 1              None        %22Upper+East+Side%22       15504.0
# 2              None                     Kentucky       34932.0
# 3              None                        Usher       26231.0
# 4              None       %23KetanjiBrownJackson           NaN
# 5              None        %22Justice+Jackson%22       82811.0
# 6              None       %22Remain+in+Mexico%22       19749.0
# 7              None          %22Clean+Air+Act%22       21310.0
# 8              None                %22The+EPA%22      115446.0
# 9              None             %23thursdayvibes       18390.0
# 10             None            %23SocialMediaDay       19022.0
# 11             None             %23ClimateCrisis       10037.0
# 12             None      %22Christian+Taliban%22       41226.0
# 13             None               %23WAKEUPWORLD       82210.0
# 14             None             %22Jon+Voight%22           NaN
# 15             None     %22ATEEZ+THE+MOVEMENT%22      101910.0
# 16             None                    McConnell       66101.0
# 17             None                         Vedo       10195.0
# 18             None         %22Eric+Bellinger%22           NaN
# 19             None              %22NICKI+EVE%22       13074.0
# 20             None          %22West+Virginia%22       19117.0
# 21             None        %22Dear+Dan+Rather%22           NaN
# 22             None                    Trump-era           NaN
# 23             None                         Theo       39438.0
# 24             None                        Kagan       22412.0
# 25             None     %22Dear+Supreme+Court%22       13176.0
# 26             None              %22%2425+USD%22       10716.0
# 27             None           %22Snake+Island%22       56158.0
# 28             None                    Superstar       37077.0
# 29             None                      Chevron           NaN
# 30             None          %22Jesus+is+Lord%22           NaN
# 31             None                        Leahy           NaN
# 32             None                        Jimbo           NaN
# 33             None          %22Judge+Jackson%22       15659.0
# 34             None                 %22My+Way%22      200351.0
# 35             None      %22Kaitlin+Armstrong%22           NaN
# 36             None       %22Independence+Day%22       17754.0
# 37             None              %22Joe+Rogan%22       21042.0
# 38             None            %22Cuphead+DLC%22           NaN
# 39             None       %22Clean+Power+Plan%22           NaN
# 40             None             %22SCOTUS+EPA%22       27673.0
# 41             None  %22Roberts+and+Kavanaugh%22           NaN
# 42             None                         NATO      556063.0
# 43             None                 %22Dune+2%22           NaN
# 44             None              %22King+Mack%22           NaN
# 45             None         %22Florida%27s+15%22           NaN
# 46             None           %22Wordle+376+X%22           NaN
# 47             None                  Confessions           NaN
# 48             None           %22Planet+Earth%22       21559.0
# 49             None      %22Daily+Quordle+157%22           NaN

# %%
# Limit the output to more than 50k tweets.
newyork_trends_50k_pd = newyork_trends_pd[newyork_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(newyork_trends_50k_pd.shape)
newyork_trends_50k_pd
# Out:
# (9, 5)
#                   name                                                url  \
# 42                NATO                   http://twitter.com/search?q=NATO
# 34              My Way           http://twitter.com/search?q=%22My+Way%22
# 8              The EPA          http://twitter.com/search?q=%22The+EPA%22
# 15  ATEEZ THE MOVEMENT  http://twitter.com/search?q=%22ATEEZ+THE+MOVEM...
# 5      Justice Jackson  http://twitter.com/search?q=%22Justice+Jackson%22
# 13        #WAKEUPWORLD         http://twitter.com/search?q=%23WAKEUPWORLD
# 16           McConnell              http://twitter.com/search?q=McConnell
# 0                Mitch                  http://twitter.com/search?q=Mitch
# 27        Snake Island     http://twitter.com/search?q=%22Snake+Island%22
#
#    promoted_content                     query  tweet_volume
# 42             None                      NATO      556063.0
# 34             None              %22My+Way%22      200351.0
# 8              None             %22The+EPA%22      115446.0
# 15             None  %22ATEEZ+THE+MOVEMENT%22      101910.0
# 5              None     %22Justice+Jackson%22       82811.0
# 13             None            %23WAKEUPWORLD       82210.0
# 16             None                 McConnell       66101.0
# 0              None                     Mitch       64900.0
# 27             None        %22Snake+Island%22       56158.0

# %%
# Save output as CSV file.
newyork_trends_50k_pd.to_csv('newyork_50k.csv', index=False)

# %% [markdown]
# ### 6. Common Trends between London and New York

# %%
# Trends in London.

# Import JSON.
import json

# Search for London.
london_trends = twitter_api.trends.place(_id=44418)

# View JSON output.
print (json.dumps(london_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "#Lionesses",
#                 "url": "http://twitter.com/search?q=%23Lionesses",
#                 "promoted_content": null,
#                 "query": "%23Lionesses",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Silverstone",
#                 "url": "http://twitter.com/search?q=Silverstone",
#                 "promoted_content": null,
#                 "query": "Silverstone",
#                 "tweet_volume": 17229
#             },
#             {
#                 "name": "Culture Secretary",
#                 "url": "http://twitter.com/search?q=%22Culture+Secretary%22",
#                 "promoted_content": null,
#                 "query": "%22Culture+Secretary%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#Pride",
#                 "url": "http://twitter.com/search?q=%23Pride",
#                 "promoted_content": null,
#                 "query": "%23Pride",
#                 "tweet_volume": 32394
#             },
#             {
#                 "name": "#BBCTennis",
#                 "url": "http://twitter.com/search?q=%23BBCTennis",
#                 "promoted_content": null,
#                 "query": "%23BBCTennis",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Shrewsbury",
#                 "url": "http://twitter.com/search?q=Shrewsbury",
#                 "promoted_content": null,
#                 "query": "Shrewsbury",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Anderson",
#                 "url": "http://twitter.com/search?q=Anderson",
#                 "promoted_content": null,
#                 "query": "Anderson",
#                 "tweet_volume": 43928
#             },
#             {
#                 "name": "Deco",
#                 "url": "http://twitter.com/search?q=Deco",
#                 "promoted_content": null,
#                 "query": "Deco",
#                 "tweet_volume": 52728
#             },
#             {
#                 "name": "Minions",
#                 "url": "http://twitter.com/search?q=Minions",
#                 "promoted_content": null,
#                 "query": "Minions",
#                 "tweet_volume": 64841
#             },
#             {
#                 "name": "#thursdayvibes",
#                 "url": "http://twitter.com/search?q=%23thursdayvibes",
#                 "promoted_content": null,
#                 "query": "%23thursdayvibes",
#                 "tweet_volume": 21664
#             },
#             {
#                 "name": "Buckingham Palace",
#                 "url": "http://twitter.com/search?q=%22Buckingham+Palace%22",
#                 "promoted_content": null,
#                 "query": "%22Buckingham+Palace%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "iPads",
#                 "url": "http://twitter.com/search?q=iPads",
#                 "promoted_content": null,
#                 "query": "iPads",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Kyrie",
#                 "url": "http://twitter.com/search?q=Kyrie",
#                 "promoted_content": null,
#                 "query": "Kyrie",
#                 "tweet_volume": 79391
#             },
#             {
#                 "name": "Usher",
#                 "url": "http://twitter.com/search?q=Usher",
#                 "promoted_content": null,
#                 "query": "Usher",
#                 "tweet_volume": 63888
#             },
#             {
#                 "name": "Nets",
#                 "url": "http://twitter.com/search?q=Nets",
#                 "promoted_content": null,
#                 "query": "Nets",
#                 "tweet_volume": 97147
#             },
#             {
#                 "name": "Durant",
#                 "url": "http://twitter.com/search?q=Durant",
#                 "promoted_content": null,
#                 "query": "Durant",
#                 "tweet_volume": 145410
#             },
#             {
#                 "name": "Logan Paul",
#                 "url": "http://twitter.com/search?q=%22Logan+Paul%22",
#                 "promoted_content": null,
#                 "query": "%22Logan+Paul%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Nadine Dorries",
#                 "url": "http://twitter.com/search?q=%22Nadine+Dorries%22",
#                 "promoted_content": null,
#                 "query": "%22Nadine+Dorries%22",
#                 "tweet_volume": 11041
#             },
#             {
#                 "name": "Ben Simmons",
#                 "url": "http://twitter.com/search?q=%22Ben+Simmons%22",
#                 "promoted_content": null,
#                 "query": "%22Ben+Simmons%22",
#                 "tweet_volume": 14334
#             },
#             {
#                 "name": "De Minaur",
#                 "url": "http://twitter.com/search?q=%22De+Minaur%22",
#                 "promoted_content": null,
#                 "query": "%22De+Minaur%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Carrie",
#                 "url": "http://twitter.com/search?q=Carrie",
#                 "promoted_content": null,
#                 "query": "Carrie",
#                 "tweet_volume": 50179
#             },
#             {
#                 "name": "Brooklyn",
#                 "url": "http://twitter.com/search?q=Brooklyn",
#                 "promoted_content": null,
#                 "query": "Brooklyn",
#                 "tweet_volume": 96937
#             },
#             {
#                 "name": "Suns",
#                 "url": "http://twitter.com/search?q=Suns",
#                 "promoted_content": null,
#                 "query": "Suns",
#                 "tweet_volume": 38976
#             },
#             {
#                 "name": "Tamworth",
#                 "url": "http://twitter.com/search?q=Tamworth",
#                 "promoted_content": null,
#                 "query": "Tamworth",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Harden",
#                 "url": "http://twitter.com/search?q=Harden",
#                 "promoted_content": null,
#                 "query": "Harden",
#                 "tweet_volume": 45252
#             },
#             {
#                 "name": "Nadal",
#                 "url": "http://twitter.com/search?q=Nadal",
#                 "promoted_content": null,
#                 "query": "Nadal",
#                 "tweet_volume": 20015
#             },
#             {
#                 "name": "Ferna",
#                 "url": "http://twitter.com/search?q=Ferna",
#                 "promoted_content": null,
#                 "query": "Ferna",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Jill Scott",
#                 "url": "http://twitter.com/search?q=%22Jill+Scott%22",
#                 "promoted_content": null,
#                 "query": "%22Jill+Scott%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Quantuma",
#                 "url": "http://twitter.com/search?q=Quantuma",
#                 "promoted_content": null,
#                 "query": "Quantuma",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Booker",
#                 "url": "http://twitter.com/search?q=Booker",
#                 "promoted_content": null,
#                 "query": "Booker",
#                 "tweet_volume": 10166
#             },
#             {
#                 "name": "Ayton",
#                 "url": "http://twitter.com/search?q=Ayton",
#                 "promoted_content": null,
#                 "query": "Ayton",
#                 "tweet_volume": 21013
#             },
#             {
#                 "name": "Wrestlemania",
#                 "url": "http://twitter.com/search?q=Wrestlemania",
#                 "promoted_content": null,
#                 "query": "Wrestlemania",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Vecna",
#                 "url": "http://twitter.com/search?q=Vecna",
#                 "promoted_content": null,
#                 "query": "Vecna",
#                 "tweet_volume": 28074
#             },
#             {
#                 "name": "Russo",
#                 "url": "http://twitter.com/search?q=Russo",
#                 "promoted_content": null,
#                 "query": "Russo",
#                 "tweet_volume": 13478
#             },
#             {
#                 "name": "Gavin Williamson",
#                 "url": "http://twitter.com/search?q=%22Gavin+Williamson%22",
#                 "promoted_content": null,
#                 "query": "%22Gavin+Williamson%22",
#                 "tweet_volume": 13988
#             },
#             {
#                 "name": "Suki",
#                 "url": "http://twitter.com/search?q=Suki",
#                 "promoted_content": null,
#                 "query": "Suki",
#                 "tweet_volume": 34925
#             },
#             {
#                 "name": "Tiny Desk",
#                 "url": "http://twitter.com/search?q=%22Tiny+Desk%22",
#                 "promoted_content": null,
#                 "query": "%22Tiny+Desk%22",
#                 "tweet_volume": 30796
#             },
#             {
#                 "name": "Van Gogh",
#                 "url": "http://twitter.com/search?q=%22Van+Gogh%22",
#                 "promoted_content": null,
#                 "query": "%22Van+Gogh%22",
#                 "tweet_volume": 13286
#             },
#             {
#                 "name": "Jason Robinson",
#                 "url": "http://twitter.com/search?q=%22Jason+Robinson%22",
#                 "promoted_content": null,
#                 "query": "%22Jason+Robinson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Neil Warnock",
#                 "url": "http://twitter.com/search?q=%22Neil+Warnock%22",
#                 "promoted_content": null,
#                 "query": "%22Neil+Warnock%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Liam Broady",
#                 "url": "http://twitter.com/search?q=%22Liam+Broady%22",
#                 "promoted_content": null,
#                 "query": "%22Liam+Broady%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Media and Sport",
#                 "url": "http://twitter.com/search?q=%22Media+and+Sport%22",
#                 "promoted_content": null,
#                 "query": "%22Media+and+Sport%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Dustin",
#                 "url": "http://twitter.com/search?q=Dustin",
#                 "promoted_content": null,
#                 "query": "Dustin",
#                 "tweet_volume": 14956
#             },
#             {
#                 "name": "Katie Boulter",
#                 "url": "http://twitter.com/search?q=%22Katie+Boulter%22",
#                 "promoted_content": null,
#                 "query": "%22Katie+Boulter%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Steve Harrington",
#                 "url": "http://twitter.com/search?q=%22Steve+Harrington%22",
#                 "promoted_content": null,
#                 "query": "%22Steve+Harrington%22",
#                 "tweet_volume": 44449
#             },
#             {
#                 "name": "St Helens",
#                 "url": "http://twitter.com/search?q=%22St+Helens%22",
#                 "promoted_content": null,
#                 "query": "%22St+Helens%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Prom",
#                 "url": "http://twitter.com/search?q=Prom",
#                 "promoted_content": null,
#                 "query": "Prom",
#                 "tweet_volume": 18907
#             },
#             {
#                 "name": "Captain Tom",
#                 "url": "http://twitter.com/search?q=%22Captain+Tom%22",
#                 "promoted_content": null,
#                 "query": "%22Captain+Tom%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Toronto",
#                 "url": "http://twitter.com/search?q=Toronto",
#                 "promoted_content": null,
#                 "query": "Toronto",
#                 "tweet_volume": 36857
#             }
#         ],
#         "as_of": "2022-06-30T20:00:41Z",
#         "created_at": "2022-06-29T05:52:37Z",
#         "locations": [
#             {
#                 "name": "London",
#                 "woeid": 44418
#             }
#         ]
#     }
# ]

# %%
# Trends in New York. 

# Search for London.
newyork_trends = twitter_api.trends.place(_id=2459115)

# View JSON output.
print (json.dumps(newyork_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Golden State",
#                 "url": "http://twitter.com/search?q=%22Golden+State%22",
#                 "promoted_content": null,
#                 "query": "%22Golden+State%22",
#                 "tweet_volume": 10508
#             },
#             {
#                 "name": "Irving",
#                 "url": "http://twitter.com/search?q=Irving",
#                 "promoted_content": null,
#                 "query": "Irving",
#                 "tweet_volume": 16728
#             },
#             {
#                 "name": "Connor",
#                 "url": "http://twitter.com/search?q=Connor",
#                 "promoted_content": null,
#                 "query": "Connor",
#                 "tweet_volume": 20230
#             },
#             {
#                 "name": "West Virginia",
#                 "url": "http://twitter.com/search?q=%22West+Virginia%22",
#                 "promoted_content": null,
#                 "query": "%22West+Virginia%22",
#                 "tweet_volume": 25682
#             },
#             {
#                 "name": "Ohtani",
#                 "url": "http://twitter.com/search?q=Ohtani",
#                 "promoted_content": null,
#                 "query": "Ohtani",
#                 "tweet_volume": 20771
#             },
#             {
#                 "name": "#ClimateCrisis",
#                 "url": "http://twitter.com/search?q=%23ClimateCrisis",
#                 "promoted_content": null,
#                 "query": "%23ClimateCrisis",
#                 "tweet_volume": 11262
#             },
#             {
#                 "name": "Mavs",
#                 "url": "http://twitter.com/search?q=Mavs",
#                 "promoted_content": null,
#                 "query": "Mavs",
#                 "tweet_volume": 10525
#             },
#             {
#                 "name": "#StrangerThings",
#                 "url": "http://twitter.com/search?q=%23StrangerThings",
#                 "promoted_content": null,
#                 "query": "%23StrangerThings",
#                 "tweet_volume": 53597
#             },
#             {
#                 "name": "Diana",
#                 "url": "http://twitter.com/search?q=Diana",
#                 "promoted_content": null,
#                 "query": "Diana",
#                 "tweet_volume": 67303
#             },
#             {
#                 "name": "Kentucky",
#                 "url": "http://twitter.com/search?q=Kentucky",
#                 "promoted_content": null,
#                 "query": "Kentucky",
#                 "tweet_volume": 38069
#             },
#             {
#                 "name": "Fournier",
#                 "url": "http://twitter.com/search?q=Fournier",
#                 "promoted_content": null,
#                 "query": "Fournier",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Fourth of July",
#                 "url": "http://twitter.com/search?q=%22Fourth+of+July%22",
#                 "promoted_content": null,
#                 "query": "%22Fourth+of+July%22",
#                 "tweet_volume": 10289
#             },
#             {
#                 "name": "Anderson",
#                 "url": "http://twitter.com/search?q=Anderson",
#                 "promoted_content": null,
#                 "query": "Anderson",
#                 "tweet_volume": 42144
#             },
#             {
#                 "name": "Kyrie",
#                 "url": "http://twitter.com/search?q=Kyrie",
#                 "promoted_content": null,
#                 "query": "Kyrie",
#                 "tweet_volume": 78570
#             },
#             {
#                 "name": "UCLA",
#                 "url": "http://twitter.com/search?q=UCLA",
#                 "promoted_content": null,
#                 "query": "UCLA",
#                 "tweet_volume": 31866
#             },
#             {
#                 "name": "Nets",
#                 "url": "http://twitter.com/search?q=Nets",
#                 "promoted_content": null,
#                 "query": "Nets",
#                 "tweet_volume": 97128
#             },
#             {
#                 "name": "Kevin Durant",
#                 "url": "http://twitter.com/search?q=%22Kevin+Durant%22",
#                 "promoted_content": null,
#                 "query": "%22Kevin+Durant%22",
#                 "tweet_volume": 108815
#             },
#             {
#                 "name": "Ben Simmons",
#                 "url": "http://twitter.com/search?q=%22Ben+Simmons%22",
#                 "promoted_content": null,
#                 "query": "%22Ben+Simmons%22",
#                 "tweet_volume": 14334
#             },
#             {
#                 "name": "Big Ten",
#                 "url": "http://twitter.com/search?q=%22Big+Ten%22",
#                 "promoted_content": null,
#                 "query": "%22Big+Ten%22",
#                 "tweet_volume": 29422
#             },
#             {
#                 "name": "Usher",
#                 "url": "http://twitter.com/search?q=Usher",
#                 "promoted_content": null,
#                 "query": "Usher",
#                 "tweet_volume": 63888
#             },
#             {
#                 "name": "Suns",
#                 "url": "http://twitter.com/search?q=Suns",
#                 "promoted_content": null,
#                 "query": "Suns",
#                 "tweet_volume": 37885
#             },
#             {
#                 "name": "Big 10",
#                 "url": "http://twitter.com/search?q=%22Big+10%22",
#                 "promoted_content": null,
#                 "query": "%22Big+10%22",
#                 "tweet_volume": 33007
#             },
#             {
#                 "name": "Pac-12",
#                 "url": "http://twitter.com/search?q=Pac-12",
#                 "promoted_content": null,
#                 "query": "Pac-12",
#                 "tweet_volume": 14868
#             },
#             {
#                 "name": "Bo Cruz",
#                 "url": "http://twitter.com/search?q=%22Bo+Cruz%22",
#                 "promoted_content": null,
#                 "query": "%22Bo+Cruz%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Rutgers",
#                 "url": "http://twitter.com/search?q=Rutgers",
#                 "promoted_content": null,
#                 "query": "Rutgers",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ayton",
#                 "url": "http://twitter.com/search?q=Ayton",
#                 "promoted_content": null,
#                 "query": "Ayton",
#                 "tweet_volume": 21013
#             },
#             {
#                 "name": "Harden",
#                 "url": "http://twitter.com/search?q=Harden",
#                 "promoted_content": null,
#                 "query": "Harden",
#                 "tweet_volume": 45252
#             },
#             {
#                 "name": "Oregon",
#                 "url": "http://twitter.com/search?q=Oregon",
#                 "promoted_content": null,
#                 "query": "Oregon",
#                 "tweet_volume": 20366
#             },
#             {
#                 "name": "#PMSFeelGoodThursday",
#                 "url": "http://twitter.com/search?q=%23PMSFeelGoodThursday",
#                 "promoted_content": null,
#                 "query": "%23PMSFeelGoodThursday",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "The NBA",
#                 "url": "http://twitter.com/search?q=%22The+NBA%22",
#                 "promoted_content": null,
#                 "query": "%22The+NBA%22",
#                 "tweet_volume": 69509
#             },
#             {
#                 "name": "AD for KD",
#                 "url": "http://twitter.com/search?q=%22AD+for+KD%22",
#                 "promoted_content": null,
#                 "query": "%22AD+for+KD%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Maxey",
#                 "url": "http://twitter.com/search?q=Maxey",
#                 "promoted_content": null,
#                 "query": "Maxey",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Lincoln Riley",
#                 "url": "http://twitter.com/search?q=%22Lincoln+Riley%22",
#                 "promoted_content": null,
#                 "query": "%22Lincoln+Riley%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Stanford",
#                 "url": "http://twitter.com/search?q=Stanford",
#                 "promoted_content": null,
#                 "query": "Stanford",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Booker",
#                 "url": "http://twitter.com/search?q=Booker",
#                 "promoted_content": null,
#                 "query": "Booker",
#                 "tweet_volume": 10166
#             },
#             {
#                 "name": "Rose Bowl",
#                 "url": "http://twitter.com/search?q=%22Rose+Bowl%22",
#                 "promoted_content": null,
#                 "query": "%22Rose+Bowl%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Miami",
#                 "url": "http://twitter.com/search?q=Miami",
#                 "promoted_content": null,
#                 "query": "Miami",
#                 "tweet_volume": 84197
#             },
#             {
#                 "name": "#NBAFreeAgency",
#                 "url": "http://twitter.com/search?q=%23NBAFreeAgency",
#                 "promoted_content": null,
#                 "query": "%23NBAFreeAgency",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Logan Paul",
#                 "url": "http://twitter.com/search?q=%22Logan+Paul%22",
#                 "promoted_content": null,
#                 "query": "%22Logan+Paul%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Herro",
#                 "url": "http://twitter.com/search?q=Herro",
#                 "promoted_content": null,
#                 "query": "Herro",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Cam Johnson",
#                 "url": "http://twitter.com/search?q=%22Cam+Johnson%22",
#                 "promoted_content": null,
#                 "query": "%22Cam+Johnson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Sixers",
#                 "url": "http://twitter.com/search?q=Sixers",
#                 "promoted_content": null,
#                 "query": "Sixers",
#                 "tweet_volume": 18489
#             },
#             {
#                 "name": "Steve Nash",
#                 "url": "http://twitter.com/search?q=%22Steve+Nash%22",
#                 "promoted_content": null,
#                 "query": "%22Steve+Nash%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Sean Marks",
#                 "url": "http://twitter.com/search?q=%22Sean+Marks%22",
#                 "promoted_content": null,
#                 "query": "%22Sean+Marks%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Utah",
#                 "url": "http://twitter.com/search?q=Utah",
#                 "promoted_content": null,
#                 "query": "Utah",
#                 "tweet_volume": 25220
#             },
#             {
#                 "name": "Pat Riley",
#                 "url": "http://twitter.com/search?q=%22Pat+Riley%22",
#                 "promoted_content": null,
#                 "query": "%22Pat+Riley%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Notre Dame",
#                 "url": "http://twitter.com/search?q=%22Notre+Dame%22",
#                 "promoted_content": null,
#                 "query": "%22Notre+Dame%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Clemson",
#                 "url": "http://twitter.com/search?q=Clemson",
#                 "promoted_content": null,
#                 "query": "Clemson",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Heat",
#                 "url": "http://twitter.com/search?q=Heat",
#                 "promoted_content": null,
#                 "query": "Heat",
#                 "tweet_volume": 119422
#             },
#             {
#                 "name": "Mikal",
#                 "url": "http://twitter.com/search?q=Mikal",
#                 "promoted_content": null,
#                 "query": "Mikal",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-06-30T20:00:50Z",
#         "created_at": "2022-06-29T12:28:25Z",
#         "locations": [
#             {
#                 "name": "New York",
#                 "woeid": 2459115
#             }
#         ]
#     }
# ]

# %%
# Find common topics.
london_trends_list = [trend['name'] for trend in london_trends[0]['trends']]

# View the output.
print(london_trends_list)
# Out:
# ['#Lionesses', 'Silverstone', 'Culture Secretary', '#Pride', '#BBCTennis', 'Shrewsbury', 'Anderson', 'Deco', 'Minions', '#thursdayvibes', 'Buckingham Palace', 'iPads', 'Kyrie', 'Usher', 'Nets', 'Durant', 'Logan Paul', 'Nadine Dorries', 'Ben Simmons', 'De Minaur', 'Carrie', 'Brooklyn', 'Suns', 'Tamworth', 'Harden', 'Nadal', 'Ferna', 'Jill Scott', 'Quantuma', 'Booker', 'Ayton', 'Wrestlemania', 'Vecna', 'Russo', 'Gavin Williamson', 'Suki', 'Tiny Desk', 'Van Gogh', 'Jason Robinson', 'Neil Warnock', 'Liam Broady', 'Media and Sport', 'Dustin', 'Katie Boulter', 'Steve Harrington', 'St Helens', 'Prom', 'Captain Tom', 'Toronto']

# %%
# Find common topics.
newyork_trends_list = [trend['name'] for trend in newyork_trends[0]['trends']]

# View the output.
print(newyork_trends_list)
# Out:
# ['Golden State', 'Irving', 'Connor', 'West Virginia', 'Ohtani', '#ClimateCrisis', 'Mavs', '#StrangerThings', 'Diana', 'Kentucky', 'Fournier', 'Fourth of July', 'Anderson', 'Kyrie', 'UCLA', 'Nets', 'Kevin Durant', 'Ben Simmons', 'Big Ten', 'Usher', 'Suns', 'Big 10', 'Pac-12', 'Bo Cruz', 'Rutgers', 'Ayton', 'Harden', 'Oregon', '#PMSFeelGoodThursday', 'The NBA', 'AD for KD', 'Maxey', 'Lincoln Riley', 'Stanford', 'Booker', 'Rose Bowl', 'Miami', '#NBAFreeAgency', 'Logan Paul', 'Herro', 'Cam Johnson', 'Sixers', 'Steve Nash', 'Sean Marks', 'Utah', 'Pat Riley', 'Notre Dame', 'Clemson', 'Heat', 'Mikal']

# %%
# Find common trends between cities.
london_trends_set = set(london_trends_list)
newyork_set = set(newyork_trends_list)

# Set the variable.
common_trends = london_trends_set.intersection(london_trends_set)

# View the output.
print(common_trends)
# Out:
# {'Quantuma', '#Pride', 'Liam Broady', 'Jason Robinson', 'Van Gogh', 'De Minaur', 'Wrestlemania', 'Katie Boulter', '#BBCTennis', 'Tiny Desk', 'Toronto', 'iPads', 'Logan Paul', '#thursdayvibes', 'Russo', 'Ben Simmons', 'Steve Harrington', 'Vecna', 'Ferna', 'Tamworth', 'Anderson', 'Nadine Dorries', 'Minions', 'Carrie', 'Booker', 'St Helens', 'Shrewsbury', 'Captain Tom', 'Dustin', 'Nets', 'Usher', 'Suns', 'Durant', 'Brooklyn', 'Prom', 'Silverstone', 'Jill Scott', 'Culture Secretary', 'Buckingham Palace', 'Ayton', 'Neil Warnock', 'Kyrie', 'Deco', 'Nadal', 'Gavin Williamson', 'Suki', 'Harden', '#Lionesses', 'Media and Sport'}

# %% [markdown]
# ---
